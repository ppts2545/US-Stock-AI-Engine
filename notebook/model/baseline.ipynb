# %%
import pandas as pd

df = pd.read_csv("../../data/processed/features/features_all.csv", parse_dates=["Date"])

# %%
features = [col for col in df.columns if col not in ["Date", "symbol", "target",
                                                      "Open", "High", "Low", "Close", "Volume"]]

X = df[features]
y = df["target"]

# %%
train = df[df["Date"] < "2022-01-01"]
test  = df[df["Date"] >= "2022-01-01"]

X_train = train[features]
y_train = train["target"]

X_test = test[features]
y_test = test["target"]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=200)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
import matplotlib.pyplot as plt

# Feature importance
importances = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)

plt.figure(figsize=(10, 5))
importances.head(15).plot(kind="bar")
plt.title("Top 15 Feature Importances")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(X_test)

print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.61      0.58      2899
#            1       0.47      0.42      0.44      2372
#
#     accuracy                           0.52      5271
#    macro avg       0.51      0.51      0.51      5271
# weighted avg       0.52      0.52      0.52      5271
